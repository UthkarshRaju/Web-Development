# %% [markdown]
# <a href="https://colab.research.google.com/github/UthkarshRaju/Web-Development/blob/master/pandas_1_20_february_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# # Pandas-1 : 20 February 2024
#
# <img src="https://media.tenor.com/W-iD9IenPZwAAAAC/angry-panda.gif">

# %%
## Downloading data

# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-02-20 14:34:05--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 142.251.2.101, 142.251.2.138, 142.251.2.139, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-02-20 14:34:05--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
! pip install pandas
# ! pip install numpy # numpy is installed by default if you try installing pandas

# %%
import numpy as np
import pandas as pd

# %%
my_file = "/content/mckinsey.csv"
# pd.read_csv("/content/mckinsey.csv")
df = pd.read_csv(my_file)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
print(df)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.shape) # rows, cols
# Out:
# (1704, 6)

# %%
# get a single col
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
print(type(df["country"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.country # if your column name had a space
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
print(type(df.country))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# get a column>> series>> info
df["country"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1704 entries, 0 to 1703
# Series name: country
# Non-Null Count  Dtype
# --------------  -----
# 1704 non-null   object
# dtypes: object(1)
# memory usage: 13.4+ KB

# %%
df[["country","continent"]]
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df["continent"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df["continent"].nunique()
# Out:
# 5

# %%
df["continent"].value_counts() # series
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
# rename any column
df.rename({"population":"no of people", "country":"desh"})
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"population":"no of people", "country":"desh"}, axis=1)
# Out:
#              desh  year  no of people continent  life_exp     gdp_cap
# 0     Afghanistan  1952       8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957       9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962      10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967      11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972      13079460      Asia    36.088  739.981106
# ...           ...   ...           ...       ...       ...         ...
# 1699     Zimbabwe  1987       9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992      10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997      11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002      11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007      12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
# inplace bool, default False
# Whether to modify the DataFrame rather than creating a new one.
# If True then value of copy is ignored.


df.rename({"population":"no of people", "country":"desh"}, axis=1, inplace=True)
df.head()
# Out:
#           desh  year  no of people continent  life_exp     gdp_cap
# 0  Afghanistan  1952       8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957       9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962      10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967      11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972      13079460      Asia    36.088  739.981106

# %%
df = pd.read_csv("/content/mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"population":"no of people", "country":"desh"}, axis=1, inplace=True)
df.head()
# Out:
#           desh  year  no of people continent  life_exp     gdp_cap
# 0  Afghanistan  1952       8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957       9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962      10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967      11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972      13079460      Asia    36.088  739.981106

# %%
df.rename(columns={"no of people":"population", "desh":"country"}, inplace=True)
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop("continent")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-238198bcf4af> in <cell line: 1>()
# ----> 1 df.drop("continent")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.drop("continent", axis=1)
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop("continent", axis=1, inplace=True)
df.head()
# Out:
#        country  year  population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.drop(columns = ["population", "country"], inplace=True)
df.head()
# Out:
#    year  life_exp     gdp_cap
# 0  1952    28.801  779.445314
# 1  1957    30.332  820.853030
# 2  1962    31.997  853.100710
# 3  1967    34.020  836.197138
# 4  1972    36.088  739.981106

# %%
# Given a dataframe consisting of 5 columns,
# which is the correct code to drop the 3rd column from the start?
df = pd.read_csv("/content/mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.columns[3]
# Out:
# 'continent'

# %%
df.drop(df.columns[3], axis=1)
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df['life_exp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
df['life_exp'] + 7 # element wise addition>> for 2 series will do matching the index
# Out:
# 0       35.801
# 1       37.332
# 2       38.997
# 3       41.020
# 4       43.088
#          ...
# 1699    69.351
# 1700    67.377
# 1701    53.809
# 1702    46.989
# 1703    50.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
df["expanded_life_exp"] = df['life_exp'] + 7

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    expanded_life_exp
# 0             35.801
# 1             37.332
# 2             38.997
# 3             41.020
# 4             43.088

# %%
# Sharath
# To: Everyone
# 9:57 PM
# can we import directly in .xls format and work instead of .csv . will the library support?
# pd.read_excel

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    expanded_life_exp
# 0             35.801
# 1             37.332
# 2             38.997
# 3             41.020
# 4             43.088

# %%
df["gdp_cap"]
# Out:
# 0       779.445314
# 1       820.853030
# 2       853.100710
# 3       836.197138
# 4       739.981106
#            ...
# 1699    706.157306
# 1700    693.420786
# 1701    792.449960
# 1702    672.038623
# 1703    469.709298
# Name: gdp_cap, Length: 1704, dtype: float64

# %%
df["population"]
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: population, Length: 1704, dtype: int64

# %%
df["gdp_cap"]*df["population"]
# Out:
# 0       6.567086e+09
# 1       7.585449e+09
# 2       8.758856e+09
# 3       9.648014e+09
# 4       9.678553e+09
#             ...
# 1699    6.508241e+09
# 1700    7.422612e+09
# 1701    9.037851e+09
# 1702    8.015111e+09
# 1703    5.782658e+09
# Length: 1704, dtype: float64

# %%
df["gdp"] = df["gdp_cap"]*df["population"]
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    expanded_life_exp           gdp
# 0             35.801  6.567086e+09
# 1             37.332  7.585449e+09
# 2             38.997  8.758856e+09
# 3             41.020  9.648014e+09
# 4             43.088  9.678553e+09

# %%
df["gdp_in_billions"] = df["gdp_cap"]*df["population"]/1000000000
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    expanded_life_exp           gdp  gdp_in_billions
# 0             35.801  6.567086e+09         6.567086
# 1             37.332  7.585449e+09         7.585449
# 2             38.997  8.758856e+09         8.758856
# 3             41.020  9.648014e+09         9.648014
# 4             43.088  9.678553e+09         9.678553

# %%
1000000000==1e9
# Out:
# True

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap',
#        'expanded_life_exp', 'gdp', 'gdp_in_billions'],
#       dtype='object')

# %%
# work with rows

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#       expanded_life_exp           gdp  gdp_in_billions
# 0                35.801  6.567086e+09         6.567086
# ...

# %%
df.index = list(range(1, 1705))
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  \
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#       expanded_life_exp           gdp  gdp_in_billions
# 1                35.801  6.567086e+09         6.567086
# ...

# %%
# explicit index >> index given by you >> loc
# implicit index >> 0,1,2.. | ..-4,-3,-2,-1 >> iloc (integer locate)

# %%
#explicit index >> index given by you >> loc
df.index = list(range(1, 1705*2-1,2))
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  \
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 5     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 7     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 9     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 3399     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 3401     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 3403     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 3405     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 3407     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#       expanded_life_exp           gdp  gdp_in_billions
# 1                35.801  6.567086e+09         6.567086
# ...

# %%
sample_df = df.head(7)
sample_df
# Out:
#         country  year  population continent  life_exp     gdp_cap  \
# 1   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 5   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 7   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 9   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 11  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 13  Afghanistan  1982    12881816      Asia    39.854  978.011439
#
#     expanded_life_exp           gdp  gdp_in_billions
# 1              35.801  6.567086e+09         6.567086
# 3              37.332  7.585449e+09         7.585449
# 5              38.997  8.758856e+09         8.758856
# 7              41.020  9.648014e+09         9.648014
# 9              43.088  9.678553e+09         9.678553
# 11             45.438  1.169766e+10        11.697659
# 13             46.854  1.259856e+10        12.598563

# %%
sample_df.index = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
# f  Afghanistan  1977    14880372      Asia    38.438  786.113360
# g  Afghanistan  1982    12881816      Asia    39.854  978.011439
#
#    expanded_life_exp           gdp  gdp_in_billions
# a             35.801  6.567086e+09         6.567086
# b             37.332  7.585449e+09         7.585449
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553
# f             45.438  1.169766e+10        11.697659
# g             46.854  1.259856e+10        12.598563

# %%
sample_df["life_exp"]#index of any column is same as index of dataframe
# Out:
# a    28.801
# b    30.332
# c    31.997
# d    34.020
# e    36.088
# f    38.438
# g    39.854
# Name: life_exp, dtype: float64

# %%
sample_df["life_exp"].index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
sample_df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
sample_df["expanded_life_exp"]
# Out:
# a    35.801
# b    37.332
# c    38.997
# d    41.020
# e    43.088
# f    45.438
# g    46.854
# Name: expanded_life_exp, dtype: float64

# %%
# implicit index >> 0,1,2.. | ..-4,-3,-2,-1 >> iloc (integer locate)
sample_df["expanded_life_exp"].iloc[-2]
# Out:
# 45.438

# %%
sample_df["expanded_life_exp"].iloc[3]
# Out:
# 41.02

# %%
# explicit index >> index given by you >> loc
sample_df["expanded_life_exp"].loc["f"]
# Out:
# 45.438

# %%
sample_df["expanded_life_exp"].loc["d"]
# Out:
# 41.02

# %%
# explicit index specifically in a series
sample_df["expanded_life_exp"]["f"]
# Out:
# 45.438

# %%
sample_df["expanded_life_exp"]["d"]
# Out:
# 41.02

# %%
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
# f  Afghanistan  1977    14880372      Asia    38.438  786.113360
# g  Afghanistan  1982    12881816      Asia    39.854  978.011439
#
#    expanded_life_exp           gdp  gdp_in_billions
# a             35.801  6.567086e+09         6.567086
# b             37.332  7.585449e+09         7.585449
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553
# f             45.438  1.169766e+10        11.697659
# g             46.854  1.259856e+10        12.598563

# %%
sample_df.iloc[-2]
# Out:
# country                     Afghanistan
# year                               1977
# population                     14880372
# continent                          Asia
# life_exp                         38.438
# gdp_cap                       786.11336
# expanded_life_exp                45.438
# gdp                  11697659230.969919
# gdp_in_billions               11.697659
# Name: f, dtype: object

# %%
sample_df.loc['f']
# Out:
# country                     Afghanistan
# year                               1977
# population                     14880372
# continent                          Asia
# life_exp                         38.438
# gdp_cap                       786.11336
# expanded_life_exp                45.438
# gdp                  11697659230.969919
# gdp_in_billions               11.697659
# Name: f, dtype: object

# %%
print(type(sample_df.iloc[-2]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# slicing

# %%
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
# f  Afghanistan  1977    14880372      Asia    38.438  786.113360
# g  Afghanistan  1982    12881816      Asia    39.854  978.011439
#
#    expanded_life_exp           gdp  gdp_in_billions
# a             35.801  6.567086e+09         6.567086
# b             37.332  7.585449e+09         7.585449
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553
# f             45.438  1.169766e+10        11.697659
# g             46.854  1.259856e+10        12.598563

# %%
sample_df[2:5] # end is not included
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    expanded_life_exp           gdp  gdp_in_billions
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553

# %%
sample_df.iloc[2:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    expanded_life_exp           gdp  gdp_in_billions
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553

# %%
# implicit indexing>> # end is not included

# %%
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
# f  Afghanistan  1977    14880372      Asia    38.438  786.113360
# g  Afghanistan  1982    12881816      Asia    39.854  978.011439
#
#    expanded_life_exp           gdp  gdp_in_billions
# a             35.801  6.567086e+09         6.567086
# b             37.332  7.585449e+09         7.585449
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553
# f             45.438  1.169766e+10        11.697659
# g             46.854  1.259856e+10        12.598563

# %%
sample_df.loc['c':'f']
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
# f  Afghanistan  1977    14880372      Asia    38.438  786.113360
#
#    expanded_life_exp           gdp  gdp_in_billions
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553
# f             45.438  1.169766e+10        11.697659

# %%
# explicit indexing>> # end is included

# %%
# single value
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106
# f  Afghanistan  1977    14880372      Asia    38.438  786.113360
# g  Afghanistan  1982    12881816      Asia    39.854  978.011439
#
#    expanded_life_exp           gdp  gdp_in_billions
# a             35.801  6.567086e+09         6.567086
# b             37.332  7.585449e+09         7.585449
# c             38.997  8.758856e+09         8.758856
# d             41.020  9.648014e+09         9.648014
# e             43.088  9.678553e+09         9.678553
# f             45.438  1.169766e+10        11.697659
# g             46.854  1.259856e+10        12.598563

# %%
# row> col
sample_df.iloc[2,5] # row, col # 2nd indexed row and 5th indexed col
# Out:
# 853.10071

# %%
sample_df.loc['c','gdp_cap']
# Out:
# 853.10071

# %%
# Abhilash
# To: Everyone
# 10:36 PM
# do we need iloc since df.iloc[:] == df[:]

sample_df.index = list(range(2,9))
sample_df
sample_df[2:4]
# Out:
#        country  year  population continent  life_exp     gdp_cap  \
# 4  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5  Afghanistan  1967    11537966      Asia    34.020  836.197138
#
#    expanded_life_exp           gdp  gdp_in_billions
# 4             38.997  8.758856e+09         8.758856
# 5             41.020  9.648014e+09         9.648014

# %%
demo = pd.Series(['a', 'b', 'c', 'd', 'e'], index=[1, 5, 3, 7, 3])
demo
# Out:
# 1    a
# 5    b
# 3    c
# 7    d
# 3    e
# dtype: object

# %%
demo.loc [1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-1e7372cbd7d0> in <cell line: 1>()
# ----> 1 demo.loc [1:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1288         if isinstance(key, slice):
#    1289             self._validate_key(key, axis)
# -> 1290             return self._get_slice_axis(key, axis=axis)
#    1291         elif com.is_bool_indexer(key):
#    1292             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
df = pd.read_csv(my_file)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[9::-3] #rows 9, 6, 3, 0 in this order
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[2]
# Out:
# country       Afghanistan
# year                 1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 2, dtype: object

# %%
df.loc[[10,2,0,15]]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 15      Albania  1967     1984060    Europe    66.220  2760.196931

# %%
df.iloc[[10,2,0,15]]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 15      Albania  1967     1984060    Europe    66.220  2760.196931

# %%
df.loc[2]
# Out:
# country       Afghanistan
# year                 1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 2, dtype: object

# %%
df.loc[[2]]
# Out:
#        country  year  population continent  life_exp    gdp_cap
# 2  Afghanistan  1962    10267083      Asia    31.997  853.10071

# %%
df.head(40)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
# How to select records from 30th to 40th row for the last 3 columns using iloc?
# iloc>> end is NOT included
df.iloc[29:40,-3:] # row, col
# Out:
#    continent  life_exp      gdp_cap
# 29    Africa    58.014  4910.416756
# 30    Africa    61.368  5745.160213
# 31    Africa    65.799  5681.358539
# 32    Africa    67.744  5023.216647
# 33    Africa    69.152  4797.295051
# 34    Africa    70.994  5288.040382
# 35    Africa    72.301  6223.367465
# 36    Africa    30.015  3520.610273
# 37    Africa    31.999  3827.940465
# 38    Africa    34.000  4269.276742
# 39    Africa    35.985  5522.776375

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.set_index('country') # creating a copy, by default inplace=False
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.set_index('country', inplace=True) # creating a copy, by default inplace=False
df
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc["Afghanistan"]
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df.reset_index()# creating a copy, by default inplace=False
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       year  population continent  life_exp     gdp_cap
# 0     1952     8425333      Asia    28.801  779.445314
# 1     1957     9240934      Asia    30.332  820.853030
# 2     1962    10267083      Asia    31.997  853.100710
# 3     1967    11537966      Asia    34.020  836.197138
# 4     1972    13079460      Asia    36.088  739.981106
# ...    ...         ...       ...       ...         ...
# 1699  1987     9216418    Africa    62.351  706.157306
# 1700  1992    10704340    Africa    60.377  693.420786
# 1701  1997    11404948    Africa    46.809  792.449960
# 1702  2002    11926563    Africa    39.989  672.038623
# 1703  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
a = pd.Series(['a', 'b', 'c'], index=[1, 2, 2])


a
# Out:
# 1    a
# 2    b
# 2    c
# dtype: object

# %%
print(a[2])
# Out:
# 2    b
# 2    c
# dtype: object

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*haUJ7elh9B4MoCqNmhtPgg.png)
